# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.5'

# %%
# !wget https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv

# %%
df = pd.read_csv("car_fuel_efficiency_2026.csv")
df
# Out:
#       model_year  origin fuel_type         drivetrain  num_doors  \
# 0           2006  Europe  Gasoline  Front-wheel drive          4
# 1           2008  Europe    Diesel  Front-wheel drive          4
# 2           1996    Asia  Gasoline  Front-wheel drive          5
# 3           1989  Europe  Gasoline  Front-wheel drive          4
# 4           1994     USA    Diesel  Front-wheel drive          3
# ...          ...     ...       ...                ...        ...
# 9995        2005     USA  Gasoline    All-wheel drive          4
# 9996        1993    Asia  Gasoline    All-wheel drive          2
# 9997        2014     USA  Gasoline    All-wheel drive          3
# 9998        2004     USA    Hybrid   Rear-wheel drive          5
# 9999        2011     USA    Diesel  Front-wheel drive          4
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                    2180              6       243.0            3870
# ...

# %%
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %%
df.fuel_type.unique()
# Out:
# <StringArray>
# ['Gasoline', 'Diesel', 'Hybrid']
# Length: 3, dtype: str

# %%
df.fuel_type.nunique()
# Out:
# 3

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(1141)

# %%
df.head(10)
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
# 5        2007     USA    Hybrid  Front-wheel drive          2
# 6        1992    Asia  Gasoline  Front-wheel drive          2
# 7        2005     USA  Gasoline  Front-wheel drive          4
# 8        1997    Asia  Gasoline   Rear-wheel drive          3
# 9        2004     USA    Diesel    All-wheel drive          5
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# ...

# %%
df.fuel_efficiency_mpg[df['origin'] == 'Asia'].max()
# Out:
# np.float64(41.2)

# %%
df.horsepower.median()
# Out:
# np.float64(254.0)

# %%
df.horsepower.mode()
# Out:
# 0    252.0
# Name: horsepower, dtype: float64

# %%
mode_power = df.horsepower.mode().item()
mode_acc = df.acceleration.mode().item()
print(mode_power, mode_acc)
values = {'horsepower': mode_power, 'acceleration': mode_acc}

df = df.fillna(value=values)
# Out:
# 252.0 18.8

# %%
df.horsepower.median()
# Out:
# np.float64(252.0)

# %%
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0          18.8                 31.9
# 1          18.8                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %%
df_asia = df[df.origin == "Asia"]

df_asia = df_asia[['model_year', 'vehicle_weight']]

# %%
X = df_asia.head(7)
X
# Out:
#     model_year  vehicle_weight
# 2         1996            4240
# 6         1992            4310
# 8         1997            4230
# 10        1978            4420
# 15        2007            3950
# 16        2021            4750
# 22        2019            4450

# %%
import numpy as np

X = np.array(X)
X
# Out:
# array([[1996, 4240],
#        [1992, 4310],
#        [1997, 4230],
#        [1978, 4420],
#        [2007, 3950],
#        [2021, 4750],
#        [2019, 4450]])

# %%
XTX = np.dot(X.T, X)
XTX
# Out:
# array([[ 28041424,  60750580],
#        [ 60750580, 131950500]])

# %%
XTX_inv = np.linalg.inv(XTX)
XTX_inv
# Out:
# array([[ 1.39675281e-05, -6.43071025e-06],
#        [-6.43071025e-06,  2.96830537e-06]])

# %%
np.dot(XTX, XTX_inv)
# Out:
# array([[ 1.00000000e+00,  2.40156389e-14],
#        [-2.61266601e-14,  1.00000000e+00]])

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# %%
w = np.dot(np.dot(XTX_inv, X.T), y)
w
# Out:
# array([0.2327492 , 0.13644777])

# %%
sum(w)
# Out:
# np.float64(0.3691969690492686)

# %%
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0          18.8                 31.9
# 1          18.8                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...
